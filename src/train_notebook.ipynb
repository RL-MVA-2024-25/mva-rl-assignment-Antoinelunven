# %%
from gymnasium.wrappers import TimeLimit
from env_hiv import HIVPatient
import random
import torch
import torch.nn as nn
import numpy as np
import torch.nn.functional as f
from  train import *
import matplotlib.pyplot as plt
import pandas as pd

# %%
agent = ProjectAgent()
# Run training
scores = agent.train(env)
# Out:
# Episode 1 | Epsilon 0.9953 | Episode return 1.05e+07 | Gradient time 0.0 | Sampling time 0.0 | Step time 7.9 | Episode time 1735832995.6 | Gradient steps 1
# Model saved to policy\model.pth
# Episode 2 | Epsilon 0.9860 | Episode return 1.08e+07 | Gradient time 0.0 | Sampling time 0.0 | Step time 7.8 | Episode time 7.8 | Gradient steps 1
# Model saved to policy\model.pth
# Episode 3 | Epsilon 0.9767 | Episode return 9.76e+06 | Gradient time 0.0 | Sampling time 0.0 | Step time 8.0 | Episode time 8.9 | Gradient steps 1
# Episode 4 | Epsilon 0.9673 | Episode return 1.09e+07 | Gradient time 0.6 | Sampling time 0.3 | Step time 7.7 | Episode time 9.2 | Gradient steps 1
# Model saved to policy\model.pth
# Episode 5 | Epsilon 0.9580 | Episode return 9.88e+06 | Gradient time 1.2 | Sampling time 0.4 | Step time 8.2 | Episode time 10.4 | Gradient steps 1
# Episode 6 | Epsilon 0.9487 | Episode return 1.24e+07 | Gradient time 1.7 | Sampling time 0.4 | Step time 9.7 | Episode time 12.5 | Gradient steps 1
# Model saved to policy\model.pth
# Episode 7 | Epsilon 0.9393 | Episode return 1.01e+07 | Gradient time 1.5 | Sampling time 0.4 | Step time 10.4 | Episode time 13.1 | Gradient steps 1
# Episode 8 | Epsilon 0.9300 | Episode return 9.47e+06 | Gradient time 1.4 | Sampling time 0.6 | Step time 10.2 | Episode time 12.9 | Gradient steps 1
# Episode 9 | Epsilon 0.9207 | Episode return 8.73e+06 | Gradient time 1.4 | Sampling time 0.5 | Step time 10.8 | Episode time 13.6 | Gradient steps 1
# Episode 10 | Epsilon 0.9113 | Episode return 8.09e+06 | Gradient time 1.7 | Sampling time 0.5 | Step time 10.7 | Episode time 13.8 | Gradient steps 2
# Episode 11 | Epsilon 0.9020 | Episode return 8.03e+06 | Gradient time 3.0 | Sampling time 0.9 | Step time 10.3 | Episode time 15.7 | Gradient steps 2
# Episode 12 | Epsilon 0.8927 | Episode return 9.59e+06 | Gradient time 3.0 | Sampling time 0.8 | Step time 10.2 | Episode time 15.3 | Gradient steps 2
# Episode 13 | Epsilon 0.8833 | Episode return 9.55e+06 | Gradient time 3.2 | Sampling time 1.1 | Step time 11.0 | Episode time 16.7 | Gradient steps 2
# Episode 14 | Epsilon 0.8740 | Episode return 9.59e+06 | Gradient time 3.0 | Sampling time 0.9 | Step time 10.8 | Episode time 16.1 | Gradient steps 2

# %%
plt.semilogy(scores)

# %%
np.savetxt("Deep_qn_9_layers", scores)

# %%
# agent = ProjectAgent()
# agent.load()

# %%
file_path = os.path.join(os.getcwd(), 'policy', 'Deep_qn_128') 
file_path2 = os.path.join(os.getcwd(), 'policy', 'Deep_qn_256') 
file_path3 = os.path.join(os.getcwd(), 'policy', 'Deep_qn_256_replay_buffer') 
file_path4 = os.path.join(os.getcwd(), 'policy', 'Deep_qn_256_replay_buffer') 
file_path5 = os.path.join(os.getcwd(), 'policy', 'Deep_qn_deep_network') 
file_path5 = os.path.join(os.getcwd(), 'policy', 'Deep_qn_9_layers') 

content128 = np.loadtxt(file_path)
content256 = np.loadtxt(file_path2)
content256_replay_buffer = np.loadtxt(file_path3)
content128_lr = np.loadtxt(file_path4)
contentdeep = np.loadtxt(file_path5)
content_9_layers = np.loadtxt(file_path6)

# %%
plt.figure()
# plt.semilogy(score_dqn, label = "DQN")
x1 = np.arange(0, len(content128))
alpha = 1
plt.semilogy(content128, label = "content128", alpha = alpha)
plt.semilogy(content256, label = "Deep_qn_256", alpha = alpha)
plt.semilogy(content256_replay_buffer, label = "Deep_qn_256_replay_buffer", alpha = alpha)
plt.semilogy(content128_lr, label = "content128_lr", alpha = alpha)
plt.semilogy(contentdeep, label = "contentdeep", alpha = alpha)
plt.semilogy(content_9_layers, label = "content_9_layers", alpha = alpha)

plt.ylabel("Reward")
plt.xlabel("Episodes")
plt.legend()
